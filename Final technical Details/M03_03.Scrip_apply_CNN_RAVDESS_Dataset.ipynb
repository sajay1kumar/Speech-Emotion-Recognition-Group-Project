# %% [markdown]
# # SER - CNN on RAVDESS (English) only

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, classification_report

# %%
df_mfcc = pd.read_csv('/content/drive/MyDrive/ravdess_mfcc_mean.csv')

# %%
df_mfcc.head()
# Out:
#                        file  emotion emotion_label  dataset     mfcc_1  \
# 0  03-01-01-01-02-02-06.wav        1       neutral  ravdess -710.79780
# 1  03-01-01-01-02-02-12.wav        1       neutral  ravdess -676.56665
# 2  03-01-03-01-01-02-06.wav        3         happy  ravdess -574.16920
# 3  03-01-03-01-01-02-12.wav        3         happy  ravdess -600.39770
# 4  03-01-04-01-01-02-02.wav        4           sad  ravdess -668.93360
#
#       mfcc_2     mfcc_3    mfcc_4    mfcc_5     mfcc_6  ...    mfcc_11  \
# 0  53.439884 -15.190397  8.793198 -0.554165 -10.416554  ...  -8.738665
# 1  52.879017   4.699556  6.543307  4.021244  -2.198579  ...  -8.157342
# 2  42.048836 -50.638577  7.814414 -3.251384 -23.890253  ... -17.436363
# 3  60.840874 -14.167917  8.259460  2.347058  -7.515831  ...  -4.999807
# 4  55.743156 -10.204071  9.223741 -5.716845  -2.916350  ...  -5.563672
#
#     mfcc_12   mfcc_13   mfcc_14   mfcc_15   mfcc_16   mfcc_17   mfcc_18  \
# 0 -2.204105 -5.876750 -3.916210 -5.274551 -3.837144 -3.003580 -3.944510
# 1 -2.291066 -7.150641 -2.611762 -0.946685 -9.005078 -5.436606 -2.201399
# 2 -2.909546 -5.733043 -9.023292 -3.229995 -9.130769 -7.111090 -0.888517
# 3  2.084753 -7.822709 -2.762776  0.491094 -5.751363 -5.363528  0.215265
# 4 -3.409941 -5.798491  0.649065 -6.239035 -3.230912 -4.998880 -2.160484
#
#     mfcc_19   mfcc_20
# 0 -5.300639 -4.574412
# 1 -7.016598 -4.207880
# 2 -3.120326 -4.910990
# 3 -4.589694 -0.819311
# 4 -5.506312 -2.222621
#
# [5 rows x 24 columns]

# %%
X = df_mfcc.iloc[:,4:].values
Y = df_mfcc['emotion_label'].values
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
X_train, X_test, y_train, y_test = train_test_split(X
                                                    , Y
                                                    , test_size=0.20
                                                    , shuffle=True
                                                    , random_state=21
                                                   )
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((384, 20), (96, 20), (384, 3), (96, 3))

# %%
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((384, 20, 1), (384, 3), (96, 20, 1), (96, 3))

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=3, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 20, 256)           1536
#
#  max_pooling1d_12 (MaxPoolin  (None, 10, 256)          0
#  g1D)
#
#  conv1d_13 (Conv1D)          (None, 10, 256)           327936
#
#  max_pooling1d_13 (MaxPoolin  (None, 5, 256)           0
#  g1D)
#
#  conv1d_14 (Conv1D)          (None, 5, 128)            163968
#
#  max_pooling1d_14 (MaxPoolin  (None, 3, 128)           0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 3, 128)            0
#
#  conv1d_15 (Conv1D)          (None, 3, 64)             41024
#
#  max_pooling1d_15 (MaxPoolin  (None, 2, 64)            0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 32)                4128
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 538,691
# Trainable params: 538,691
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
model_history=model.fit(X_train, y_train, batch_size=16, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 24/24 [==============================] - 3s 75ms/step - loss: 6.2938 - accuracy: 0.3568 - val_loss: 1.7942 - val_accuracy: 0.3229
# Epoch 2/100
# 24/24 [==============================] - 2s 68ms/step - loss: 1.4342 - accuracy: 0.3646 - val_loss: 1.1000 - val_accuracy: 0.3229
# Epoch 3/100
# 24/24 [==============================] - 1s 62ms/step - loss: 1.1043 - accuracy: 0.4271 - val_loss: 1.0675 - val_accuracy: 0.4375
# Epoch 4/100
# 24/24 [==============================] - 1s 56ms/step - loss: 1.0829 - accuracy: 0.3854 - val_loss: 1.0671 - val_accuracy: 0.4375
# Epoch 5/100
# 24/24 [==============================] - 1s 57ms/step - loss: 1.0658 - accuracy: 0.4297 - val_loss: 1.0827 - val_accuracy: 0.3333
# Epoch 6/100
# 24/24 [==============================] - 2s 66ms/step - loss: 1.0585 - accuracy: 0.4036 - val_loss: 1.0978 - val_accuracy: 0.4271
# Epoch 7/100
# 24/24 [==============================] - 1s 59ms/step - loss: 1.0650 - accuracy: 0.4531 - val_loss: 1.0758 - val_accuracy: 0.4479
# Epoch 8/100
# 24/24 [==============================] - 2s 71ms/step - loss: 1.0667 - accuracy: 0.4036 - val_loss: 1.0528 - val_accuracy: 0.4792
# Epoch 9/100
# 24/24 [==============================] - 1s 60ms/step - loss: 1.0572 - accuracy: 0.4557 - val_loss: 1.0634 - val_accuracy: 0.3229
# Epoch 10/100
# 24/24 [==============================] - 1s 60ms/step - loss: 1.0229 - accuracy: 0.4349 - val_loss: 1.0568 - val_accuracy: 0.4062
# Epoch 11/100
# 24/24 [==============================] - 1s 33ms/step - loss: 1.0308 - accuracy: 0.4115 - val_loss: 1.0520 - val_accuracy: 0.3646
# Epoch 12/100
# 24/24 [==============================] - 1s 33ms/step - loss: 1.0293 - accuracy: 0.4844 - val_loss: 1.0578 - val_accuracy: 0.4688
# Epoch 13/100
# 24/24 [==============================] - 1s 34ms/step - loss: 1.0272 - accuracy: 0.4557 - val_loss: 1.0295 - val_accuracy: 0.4688
# Epoch 14/100
# 24/24 [==============================] - 1s 33ms/step - loss: 1.0083 - accuracy: 0.4583 - val_loss: 1.0092 - val_accuracy: 0.4688
# Epoch 15/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9707 - accuracy: 0.5078 - val_loss: 1.0536 - val_accuracy: 0.4688
# Epoch 16/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9954 - accuracy: 0.4479 - val_loss: 1.0028 - val_accuracy: 0.4688
# Epoch 17/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9824 - accuracy: 0.4635 - val_loss: 0.9718 - val_accuracy: 0.4896
# Epoch 18/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9426 - accuracy: 0.4792 - val_loss: 1.0577 - val_accuracy: 0.4688
# Epoch 19/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.9746 - accuracy: 0.5000 - val_loss: 1.0036 - val_accuracy: 0.4792
# Epoch 20/100
# 24/24 [==============================] - 1s 33ms/step - loss: 1.0393 - accuracy: 0.4818 - val_loss: 1.0725 - val_accuracy: 0.4583
# Epoch 21/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.9742 - accuracy: 0.5208 - val_loss: 0.9621 - val_accuracy: 0.4792
# Epoch 22/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9690 - accuracy: 0.5078 - val_loss: 0.9809 - val_accuracy: 0.4583
# Epoch 23/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9665 - accuracy: 0.5365 - val_loss: 0.9567 - val_accuracy: 0.4896
# Epoch 24/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9096 - accuracy: 0.5521 - val_loss: 0.9480 - val_accuracy: 0.4792
# Epoch 25/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.9272 - accuracy: 0.5443 - val_loss: 1.1137 - val_accuracy: 0.5000
# Epoch 26/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9048 - accuracy: 0.5391 - val_loss: 0.9919 - val_accuracy: 0.4479
# Epoch 27/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9264 - accuracy: 0.5521 - val_loss: 0.9572 - val_accuracy: 0.5104
# Epoch 28/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.8997 - accuracy: 0.5625 - val_loss: 1.1019 - val_accuracy: 0.4792
# Epoch 29/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.9095 - accuracy: 0.5625 - val_loss: 0.9480 - val_accuracy: 0.5104
# Epoch 30/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.9529 - accuracy: 0.5339 - val_loss: 1.0083 - val_accuracy: 0.4479
# Epoch 31/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.8830 - accuracy: 0.5625 - val_loss: 1.0168 - val_accuracy: 0.5104
# Epoch 32/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.8490 - accuracy: 0.5833 - val_loss: 1.0747 - val_accuracy: 0.4688
# Epoch 33/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.8451 - accuracy: 0.5703 - val_loss: 1.0894 - val_accuracy: 0.4688
# Epoch 34/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.8186 - accuracy: 0.6094 - val_loss: 0.9034 - val_accuracy: 0.5312
# Epoch 35/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.8351 - accuracy: 0.5781 - val_loss: 1.0297 - val_accuracy: 0.5208
# Epoch 36/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.8117 - accuracy: 0.5859 - val_loss: 1.2652 - val_accuracy: 0.5000
# Epoch 37/100
# 24/24 [==============================] - 1s 32ms/step - loss: 0.8366 - accuracy: 0.5990 - val_loss: 0.9444 - val_accuracy: 0.5104
# Epoch 38/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.9185 - accuracy: 0.5417 - val_loss: 1.0472 - val_accuracy: 0.5000
# Epoch 39/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.8350 - accuracy: 0.6016 - val_loss: 1.2763 - val_accuracy: 0.5104
# Epoch 40/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.7954 - accuracy: 0.6146 - val_loss: 0.8790 - val_accuracy: 0.5521
# Epoch 41/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.7620 - accuracy: 0.6380 - val_loss: 1.3660 - val_accuracy: 0.5208
# Epoch 42/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.7161 - accuracy: 0.6562 - val_loss: 0.9295 - val_accuracy: 0.6250
# Epoch 43/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.7797 - accuracy: 0.6536 - val_loss: 1.0697 - val_accuracy: 0.5833
# Epoch 44/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.7489 - accuracy: 0.6198 - val_loss: 1.1119 - val_accuracy: 0.5833
# Epoch 45/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.7238 - accuracy: 0.6510 - val_loss: 1.0790 - val_accuracy: 0.5938
# Epoch 46/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6808 - accuracy: 0.6823 - val_loss: 1.0194 - val_accuracy: 0.5000
# Epoch 47/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6481 - accuracy: 0.6693 - val_loss: 1.0900 - val_accuracy: 0.6354
# Epoch 48/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6880 - accuracy: 0.6797 - val_loss: 0.8219 - val_accuracy: 0.6354
# Epoch 49/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6803 - accuracy: 0.6693 - val_loss: 0.9694 - val_accuracy: 0.5000
# Epoch 50/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.8508 - accuracy: 0.5807 - val_loss: 0.9162 - val_accuracy: 0.6042
# Epoch 51/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6679 - accuracy: 0.6562 - val_loss: 0.8743 - val_accuracy: 0.6667
# Epoch 52/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6241 - accuracy: 0.7005 - val_loss: 1.0190 - val_accuracy: 0.6146
# Epoch 53/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5694 - accuracy: 0.7161 - val_loss: 1.0457 - val_accuracy: 0.5938
# Epoch 54/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6291 - accuracy: 0.6745 - val_loss: 0.9620 - val_accuracy: 0.6667
# Epoch 55/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6197 - accuracy: 0.7214 - val_loss: 0.8988 - val_accuracy: 0.6458
# Epoch 56/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6295 - accuracy: 0.6979 - val_loss: 0.9954 - val_accuracy: 0.6458
# Epoch 57/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6286 - accuracy: 0.6875 - val_loss: 0.8551 - val_accuracy: 0.6354
# Epoch 58/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5809 - accuracy: 0.7005 - val_loss: 1.0531 - val_accuracy: 0.6250
# Epoch 59/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6076 - accuracy: 0.7135 - val_loss: 0.8886 - val_accuracy: 0.6458
# Epoch 60/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5481 - accuracy: 0.7188 - val_loss: 0.9462 - val_accuracy: 0.6458
# Epoch 61/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6572 - accuracy: 0.6849 - val_loss: 1.0031 - val_accuracy: 0.6146
# Epoch 62/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5789 - accuracy: 0.7161 - val_loss: 1.0262 - val_accuracy: 0.6875
# Epoch 63/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5875 - accuracy: 0.7057 - val_loss: 0.9410 - val_accuracy: 0.6562
# Epoch 64/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5275 - accuracy: 0.7474 - val_loss: 0.9874 - val_accuracy: 0.6354
# Epoch 65/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6371 - accuracy: 0.6875 - val_loss: 1.0954 - val_accuracy: 0.5417
# Epoch 66/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6049 - accuracy: 0.7109 - val_loss: 1.2477 - val_accuracy: 0.6354
# Epoch 67/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5061 - accuracy: 0.7656 - val_loss: 1.1316 - val_accuracy: 0.6458
# Epoch 68/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5249 - accuracy: 0.7396 - val_loss: 0.9480 - val_accuracy: 0.6458
# Epoch 69/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4607 - accuracy: 0.7578 - val_loss: 0.8758 - val_accuracy: 0.6250
# Epoch 70/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5286 - accuracy: 0.7240 - val_loss: 1.1098 - val_accuracy: 0.5833
# Epoch 71/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5175 - accuracy: 0.7422 - val_loss: 1.0457 - val_accuracy: 0.6667
# Epoch 72/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.5513 - accuracy: 0.7422 - val_loss: 0.9116 - val_accuracy: 0.6667
# Epoch 73/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5482 - accuracy: 0.7135 - val_loss: 0.9248 - val_accuracy: 0.6458
# Epoch 74/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4795 - accuracy: 0.7604 - val_loss: 0.8417 - val_accuracy: 0.6458
# Epoch 75/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4665 - accuracy: 0.7552 - val_loss: 1.1377 - val_accuracy: 0.5833
# Epoch 76/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5336 - accuracy: 0.7292 - val_loss: 1.1658 - val_accuracy: 0.6250
# Epoch 77/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4953 - accuracy: 0.7656 - val_loss: 0.8514 - val_accuracy: 0.6667
# Epoch 78/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4659 - accuracy: 0.7526 - val_loss: 1.3916 - val_accuracy: 0.6354
# Epoch 79/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4637 - accuracy: 0.7682 - val_loss: 0.8814 - val_accuracy: 0.6042
# Epoch 80/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4886 - accuracy: 0.7188 - val_loss: 1.5773 - val_accuracy: 0.5833
# Epoch 81/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4747 - accuracy: 0.7552 - val_loss: 1.0688 - val_accuracy: 0.6250
# Epoch 82/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4629 - accuracy: 0.7786 - val_loss: 1.5872 - val_accuracy: 0.5417
# Epoch 83/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4504 - accuracy: 0.7474 - val_loss: 1.0210 - val_accuracy: 0.6458
# Epoch 84/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4685 - accuracy: 0.7552 - val_loss: 1.2355 - val_accuracy: 0.6458
# Epoch 85/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5133 - accuracy: 0.7526 - val_loss: 0.9005 - val_accuracy: 0.6667
# Epoch 86/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4803 - accuracy: 0.7526 - val_loss: 1.2099 - val_accuracy: 0.5938
# Epoch 87/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4063 - accuracy: 0.7786 - val_loss: 1.5913 - val_accuracy: 0.6354
# Epoch 88/100
# 24/24 [==============================] - 1s 35ms/step - loss: 0.5393 - accuracy: 0.7500 - val_loss: 1.0022 - val_accuracy: 0.6458
# Epoch 89/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4071 - accuracy: 0.7839 - val_loss: 1.3056 - val_accuracy: 0.5729
# Epoch 90/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4670 - accuracy: 0.7370 - val_loss: 2.2712 - val_accuracy: 0.6146
# Epoch 91/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4498 - accuracy: 0.7656 - val_loss: 0.8657 - val_accuracy: 0.5833
# Epoch 92/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.5546 - accuracy: 0.7109 - val_loss: 1.8749 - val_accuracy: 0.5833
# Epoch 93/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4724 - accuracy: 0.7604 - val_loss: 0.9122 - val_accuracy: 0.6354
# Epoch 94/100
# 24/24 [==============================] - 1s 33ms/step - loss: 0.4460 - accuracy: 0.7630 - val_loss: 1.4039 - val_accuracy: 0.6146
# Epoch 95/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4662 - accuracy: 0.7552 - val_loss: 1.4384 - val_accuracy: 0.6354
# Epoch 96/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4164 - accuracy: 0.7760 - val_loss: 1.0560 - val_accuracy: 0.6146
# Epoch 97/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3889 - accuracy: 0.7812 - val_loss: 0.8982 - val_accuracy: 0.6458
# Epoch 98/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3905 - accuracy: 0.7891 - val_loss: 1.7713 - val_accuracy: 0.5521
# Epoch 99/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.3874 - accuracy: 0.7812 - val_loss: 1.1551 - val_accuracy: 0.5938
# Epoch 100/100
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4054 - accuracy: 0.7839 - val_loss: 1.3250 - val_accuracy: 0.6354

# %%
print("Accuracy of our model on test data : " , model.evaluate(X_test,y_test)[1]*100 , "%")

epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = model_history.history['accuracy']
train_loss = model_history.history['loss']
test_acc = model_history.history['val_accuracy']
test_loss = model_history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 3/3 [==============================] - 0s 11ms/step - loss: 1.3250 - accuracy: 0.6354
# Accuracy of our model on test data :  63.54166865348816 %

# %%
pred_test = model.predict(X_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0              sad       neutral
# 1              sad           sad
# 2              sad           sad
# 3              sad       neutral
# 4            happy         happy
# 5              sad           sad
# 6            happy         happy
# 7              sad           sad
# 8            happy         happy
# 9            happy         happy

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        happy       0.71      0.81      0.76        31
#      neutral       0.00      0.00      0.00        23
#          sad       0.59      0.86      0.70        42
#
#     accuracy                           0.64        96
#    macro avg       0.43      0.55      0.49        96
# weighted avg       0.49      0.64      0.55        96
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
